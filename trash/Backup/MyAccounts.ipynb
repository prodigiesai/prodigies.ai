# %%
import jwt
from cryptography.hazmat.primitives.asymmetric import ec
import time
import requests
from coinbase.rest import RESTClient
from json import dumps
import pandas as pd


api_key = "organizations/64d6b82e-d84a-4359-a5e1-02c45d6d5a94/apiKeys/eb358a7e-0963-41bf-94e4-871228021a10"
api_secret = "-----BEGIN EC PRIVATE KEY-----\nMHcCAQEEIFhGsJvjGro9vkBk9O+LOyBTSP2T419zGqYho+g73A9HoAoGCCqGSM49\nAwEHoUQDQgAEGCBbxSHe3pScIvvTlwSbauoeP9HMLvHW+iKpdAGjtKqBehZ5Q+s8\ntqdcmGlMqgXrSt/S27WLC4SvxcDFZ3VFeQ==\n-----END EC PRIVATE KEY-----\n"

client = RESTClient(api_key=api_key, api_secret=api_secret)

accounts = client.get_accounts(250)



# Convert the accounts list to a DataFrame for clear table structure
accounts_data = [
    {
        'UUID': account.uuid,
        'Name': account.name,
        'Currency': account.currency,
        'Available Balance': account.available_balance['value'],
        'Balance Currency': account.available_balance['currency'],
        'Default': account.default,
        'Active': account.active,
        'Type': account.type,
        'Created At': account.created_at,
        'Updated At': account.updated_at
    }
    for account in accounts.accounts  # Assuming `accounts.accounts` is iterable
]

# Create a DataFrame from the account data
df_accounts = pd.DataFrame(accounts_data)
df_accounts
# Display the DataFrame as a table in Jupyter Notebook

# Ensure 'Available Balance' is treated as a numeric type
df_accounts['Available Balance'] = pd.to_numeric(df_accounts['Available Balance'], errors='coerce')

# Filter the DataFrame for accounts where 'Available Balance' is greater than zero
df_accounts_with_balance = df_accounts[df_accounts['Available Balance'] > 0]

# Display the filtered DataFrame
df_accounts_with_balance
# Out:
#                                     UUID         Name Currency  \
# 7   babff4f9-dd3b-551b-b769-bf1bd1601df2   SOL Wallet      SOL
# 17  1fa6d897-20e2-5c5b-8cbb-43de9e954d7f   ADA Wallet      ADA
# 70  a27f26b1-8b6e-57fc-b289-e5972c6c1bd2  USDC Wallet     USDC
# 75  2f70928e-3697-5ea8-ad26-00ac7d92f569   USD Wallet      USD
# 76  71183cbd-8972-503f-96e4-4b9fc90d11a7   BCH Wallet      BCH
# 77  61cdba5c-6f3e-5ca3-86c5-421984b641a6   ETH Wallet      ETH
# 79  070b18bc-7098-5515-bbdd-ced28f7b7733    My Wallet      BTC
#
#     Available Balance Balance Currency  Default  Active                 Type  \
# 7        1.633600e-04              SOL     True    True  ACCOUNT_TYPE_CRYPTO
# 17       5.190400e-02              ADA     True    True  ACCOUNT_TYPE_CRYPTO
# 70       3.415510e-01             USDC     True    True  ACCOUNT_TYPE_CRYPTO
# 75       4.088749e+01              USD    False    True    ACCOUNT_TYPE_FIAT
# 76       1.445800e-04              BCH     True    True  ACCOUNT_TYPE_CRYPTO
# 77       5.100802e-09              ETH     True    True  ACCOUNT_TYPE_CRYPTO
# 79       1.402455e-02              BTC     True    True  ACCOUNT_TYPE_CRYPTO
#
#                   Created At                Updated At
# 7   2021-07-08T14:07:14.351Z  2024-02-11T02:11:45.529Z
# 17  2021-07-08T14:07:14.270Z  2024-02-08T16:50:20.351Z
# 70  2019-03-04T18:35:13.076Z  2024-02-08T16:50:20.453Z
# 75  2017-12-19T01:13:17.964Z  2024-11-18T19:56:47.048Z
# 76  2017-12-14T01:48:49.092Z  2020-12-27T16:44:49.393Z
# 77  2017-12-09T23:43:07.171Z  2022-11-30T15:22:55.794Z
# 79  2013-12-19T02:19:20.472Z  2024-11-14T19:36:36.341Z
